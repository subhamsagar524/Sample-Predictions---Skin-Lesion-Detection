# %% [markdown]
# # Skin Lesion - Sample Predictions

# %%
# Import required libraries
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
# Prediction
def predict(url):
    image_width, image_height = 224,224
    img = image.load_img(url, target_size=(image_width, image_height))
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis = 0)
    img/= 255.
    model = load_model('modelVVG16.h5')
    result = model.predict(img)
    if result[0][0] >= 0.5:
        prediction = 'Malignant'
    else:
        prediction = 'Benign'
    return prediction

# %% [markdown]
# ## Predictions

# %% [markdown]
# ### Benign

# %%
url = '/Skin Lesion Detection/test/benign/1023.jpg'
img = image.load_img(url, target_size=(224,224))
print('Predicted skin cancer: ', predict(url))
img
# Out:
# 1/1 [==============================] - 0s 330ms/step
# Predicted skin cancer:  Benign
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
url = '/Skin Lesion Detection/test/benign/1003.jpg'
img = image.load_img(url, target_size=(224,224))
print('Predicted skin cancer: ', predict(url))
img
# Out:
# 1/1 [==============================] - 0s 280ms/step
# Predicted skin cancer:  Benign
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
url = '/Skin Lesion Detection/test/benign/1139.jpg'
img = image.load_img(url, target_size=(224,224))
print('Predicted skin cancer: ', predict(url))
img
# Out:
# 1/1 [==============================] - 0s 274ms/step
# Predicted skin cancer:  Benign
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
url = '/Skin Lesion Detection/test/benign/1350.jpg'
img = image.load_img(url, target_size=(224,224))
print('Predicted skin cancer: ', predict(url))
img
# Out:
# 1/1 [==============================] - 0s 290ms/step
# Predicted skin cancer:  Benign
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
url = '/Skin Lesion Detection/test/benign/1378.jpg'
img = image.load_img(url, target_size=(224,224))
print('Predicted skin cancer: ', predict(url))
img
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000012713F1D870> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 323ms/step
# Predicted skin cancer:  Benign
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %% [markdown]
# ### Malignant

# %%
url = '/Skin Lesion Detection/test/malignant/1089.jpg'
img = image.load_img(url, target_size=(224,224))
print('Predicted skin cancer: ', predict(url))
img
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000012713927D90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 280ms/step
# Predicted skin cancer:  Malignant
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
url = '/Skin Lesion Detection/test/malignant/1173.jpg'
img = image.load_img(url, target_size=(224,224))
print('Predicted skin cancer: ', predict(url))
img
# Out:
# 1/1 [==============================] - 0s 313ms/step
# Predicted skin cancer:  Malignant
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
url = '/Skin Lesion Detection/test/malignant/1254.jpg'
img = image.load_img(url, target_size=(224,224))
print('Predicted skin cancer: ', predict(url))
img
# Out:
# 1/1 [==============================] - 0s 310ms/step
# Predicted skin cancer:  Malignant
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
url = '/Skin Lesion Detection/test/malignant/1267.jpg'
img = image.load_img(url, target_size=(224,224))
print('Predicted skin cancer: ', predict(url))
img
# Out:
# 1/1 [==============================] - 0s 290ms/step
# Predicted skin cancer:  Malignant
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
url = '/Skin Lesion Detection/test/malignant/1322.jpg'
img = image.load_img(url, target_size=(224,224))
print('Predicted skin cancer: ', predict(url))
img
# Out:
# 1/1 [==============================] - 0s 310ms/step
# Predicted skin cancer:  Malignant
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>
